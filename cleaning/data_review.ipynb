# %%
import pandas as pd
from data_importer_boe import load_data

# %%
df = load_data()

# %%
df
# Out:
#      documento metadatos     identificador  \
# 0         \n      \n      BOE-A-2020-13601
# 1         \n      \n      BOE-A-2020-13599
# 2         \n      \n      BOE-A-2020-13600
# 3         \n      \n      BOE-A-2020-13603
# 4         \n      \n      BOE-A-2020-13602
# ...        ...       ...               ...
# 6910      \n      \n      BOE-A-2020-13908
# 6911      \n      \n      BOE-A-2020-13909
# 6912      \n      \n      BOE-A-2020-13912
# 6913      \n      \n      BOE-A-2020-13910
# 6914      \n      \n      BOE-A-2020-13911
#
#                                                  titulo diario  diario_numero  \
# 0     Resolución de 22 de octubre de 2020, de la Sec...    BOE            291
# 1     Resolución de 22 de octubre de 2020, de la Sec...    BOE            291
# 2     Resolución de 22 de octubre de 2020, de la Sec...    BOE            291
# 3     Resolución de 21 de octubre de 2020, del Real ...    BOE            291
# ...

# %%
df.describe()
# Out:
#        diario_numero  fecha_disposicion  fecha_publicacion  fecha_vigencia  \
# count    6915.000000       1.692000e+03       6.915000e+03    9.800000e+01
# mean      301.251482       2.020094e+07       2.020112e+07    2.020163e+07
# std         7.081774       2.610171e+03       8.286774e+00    3.299797e+03
# min       290.000000       2.012121e+07       2.020110e+07    2.018042e+07
# 25%       295.000000       2.020103e+07       2.020111e+07    2.020111e+07
# 50%       300.000000       2.020110e+07       2.020111e+07    2.020112e+07
# 75%       308.000000       2.020111e+07       2.020112e+07    2.020112e+07
# max       313.000000       2.020122e+07       2.020113e+07    2.021031e+07
#
#        fecha_derogacion  pagina_inicial   pagina_final  \
# count               0.0     6915.000000    6915.000000
# mean                NaN    66559.469414   66561.153290
# std                 NaN    19982.828525   19985.286181
# min                 NaN    51652.000000   51652.000000
# ...

# %%
df['titulo']
# Out:
# 0       Resolución de 22 de octubre de 2020, de la Sec...
# 1       Resolución de 22 de octubre de 2020, de la Sec...
# 2       Resolución de 22 de octubre de 2020, de la Sec...
# 3       Resolución de 21 de octubre de 2020, del Real ...
# 4       Resolución de 21 de octubre de 2020, del Real ...
#                               ...
# 6910    Sala Segunda. Sentencia 136/2020, de 6 de octu...
# 6911    Sala Segunda. Sentencia 137/2020, de 6 de octu...
# 6912    Sala Segunda. Sentencia 140/2020, de 6 de octu...
# 6913    Sala Segunda. Sentencia 138/2020, de 6 de octu...
# 6914    Sala Segunda. Sentencia 139/2020, de 6 de octu...
# Name: titulo, Length: 6915, dtype: object

# %%
df['analisis_notas'].value_counts()
# Out:
# \n          50
# Name: analisis_notas, dtype: int64

# %%
df['analisis_materias'].value_counts()
# Out:
# \n          273
# Name: analisis_materias, dtype: int64

# %%
df['analisis_alertas'].value_counts()
# Out:
# \n          823
# Name: analisis_alertas, dtype: int64

# %%
df['referencias_anteriores'].value_counts()
# Out:
# \n            364
# Name: referencias_anteriores, dtype: int64

# %%
df['referencias_posteriores'].value_counts()
# Out:
# \n            50
# Name: referencias_posteriores, dtype: int64

# %%
df.dtypes
# Out:
# documento                     object
# metadatos                     object
# identificador                 object
# titulo                        object
# diario                        object
# diario_numero                  int64
# seccion                       object
# subseccion                    object
# departamento                  object
# rango                         object
# numero_oficial                object
# fecha_disposicion            float64
# fecha_publicacion              int64
# fecha_vigencia               float64
# fecha_derogacion             float64
# letra_imagen                  object
# pagina_inicial                 int64
# pagina_final                   int64
# suplemento_letra_imagen      float64
# suplemento_pagina_inicial    float64
# suplemento_pagina_final      float64
# estatus_legislativo           object
# origen_legislativo            object
# estado_consolidacion          object
# judicialmente_anulada         object
# ...

# %%
df['suplemento_pagina_inicial'].value_counts()
# Out:
# Series([], Name: suplemento_pagina_inicial, dtype: int64)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d1607224a87d> in <module>
#       1 from peony import oauth_dance
#       2 from peony import PeonyClient
# ----> 3 tokens = oauth_dance(consumer_key, consumer_secret)
#       4 peony_client = PeonyClient(**tokens)
#
# NameError: name 'consumer_key' is not defined

# %%
len(res)
# Out:
# 200
